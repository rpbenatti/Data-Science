# %% [markdown]
# <a href="https://colab.research.google.com/github/rpbenatti/Data-Science/blob/master/Matplotlib_Guide_For_People_In_A_Hurry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <html><b>Matplotlib Guide For People In A Hurry</b></html>
#
# https://towardsdatascience.com/all-your-matplotlib-questions-answered-420dd95cb4ff

# %% [markdown]
# <html><b>STARTING TIPS</b></html>

# %% [markdown]
# First and foremost, make sure you import matplotlib.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# In Jupyter Notebook, you can include this line below so that you do not have to call plt.show() every time that you want to make a plot.

# %%
# %matplotlib inline

# %% [markdown]
# Another handy tip is if you don’t want this annoying message to appear
# <matplotlib.collections.PathCollection at 0x1182bc710>
# just add a semicolon to your line of code as shown in the second picture below.

# %% [markdown]
# <html><b>Before:</b></html>

# %%
plt.scatter(1, 1)

# %% [markdown]
# <html><b>After:</b></html>

# %%
plt.scatter(1, 1);

# %% [markdown]
# <html><b>PLOTS AND SUBPLOTS</b></html>

# %% [markdown]
# Q: How do I increase the size of my figure?

# %%
plt.figure(figsize=(10,5))
plt.scatter(1, 1);

# %% [markdown]
# Q: What is a subplot? How do I create and navigate subplots?

# %%
for i in range (1, 5):
   plt.subplot(2, 2, i)
   plt.text(0.5,0.5, str((2, 2, i)), ha='center', fontsize = 10)

# %% [markdown]
# Q: My subplot arrangement does not look very nice. How do I fix it?

# %% [markdown]
# We can fix it by calling plt.tight_layout(). It cleans up the padding between subplots for a cleaner look

# %%
for i in range (1, 5):
   plt.subplot(2, 2, i)
   plt.text(0.5,0.5, str((2, 2, i)), ha='center', fontsize = 10)
   plt.tight_layout()

# %% [markdown]
# Q: How do I add gridlines to my plots?

# %%
plt.scatter(1, 1)
plt.grid(True)

# %% [markdown]
# <html><b>STYLES AND PROPERTIES</b></html>

# %% [markdown]
# Q: How do I change my line colors/width/style?

# %% [markdown]
# You can pass in the arguments color, linewidth, and linestyle.

# %%
x = [0, 2, 4, 6, 8]
y = [1, 3, 5, 7, 9]

plt.figure(figsize=(8,8))
plt.subplot(2, 2, 1)
plt.plot(x, y, color = 'red' , linewidth = 2, linestyle = ':')
plt.subplot(2, 2, 2)
plt.plot(x, y, color = 'green' , linewidth = 3, linestyle = '-.')
plt.subplot(2, 2, 3)
plt.plot(x, y, color = 'orange' , linewidth = 4, linestyle = '--')
plt.subplot(2, 2, 4)
plt.plot(x, y, color = 'blue' , linewidth = 5, linestyle = '-')
plt.tight_layout()

# %% [markdown]
# Q: How do I change my marker style or color?

# %% [markdown]
# You can pass in the arguments marker and color like below.

# %%
m = ['^', '3', 'P', 'x', '_',
     'v', '2', 'p', '+', '|',
     'o', '1', 's', 'H', 'd',
     ',', '4', '8', 'h', 'D',
     '<', '>', '*', 'X', '']

c = ['red', 'green', 'blue', 'orange', 'purple',
     'red', 'green', 'blue', 'orange', 'purple',
     'red', 'green', 'blue', 'orange', 'purple',
     'red', 'green', 'blue', 'orange', 'purple',
     'red', 'green', 'blue', 'orange', 'purple']

for i, item in enumerate(m):
    plt.subplot(5, 5, i+1)
    plt.scatter(1, 1, marker = item, color = c[i])

plt.tight_layout()

# %% [markdown]
# Q: How do I change the transparency for my lines?

# %% [markdown]
# Pass in the alpha parameter to your plot. Alpha can be set from 0 to 1, where 0 is completely transparent and 1 is no transparency.

# %%
plt.plot(x, y, alpha = 0.1)
